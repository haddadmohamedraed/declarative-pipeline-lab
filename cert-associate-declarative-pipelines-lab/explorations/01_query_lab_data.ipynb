# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.orders_bronze;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.status_bronze;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.status_silver;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.customers_cdc_bronze;

# %%
# %sql
DESCRIBE TABLE
workspace.certification_pipeline_lab.orders_bronze;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.orders_silver;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.orders_strict_validation;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.gold_orders_by_date
ORDER BY order_date;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.orders_gold_input;

# %%
# %sql
SELECT
    order_id,
    country_code,
    country_name,
    capital,
    amount,
    notifications

FROM workspace.certification_pipeline_lab.orders_enriched_silver;

# %%
# %sql
SELECT
    order_id,
    customer_id,
    country_name,
    amount,
    status,
    status_timestamp

FROM workspace.certification_pipeline_lab.full_order_info_gold

ORDER BY order_id;

# %%
# %sql
SELECT
    order_id,
    order_timestamp,
    status,
    status_timestamp,
    status_delay

FROM workspace.certification_pipeline_lab.order_status_events_streaming

ORDER BY order_id, status_timestamp;

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.customers_scd1

# %%
# %sql
SELECT *
FROM workspace.certification_pipeline_lab.customers_scd2

# %%
# %sql
SELECT *
FROM event_log('f7be284d-1697-497a-b921-e8933bda8749')
ORDER BY timestamp DESC
LIMIT 100;
